# %% [markdown]
# # Real-time Anomaly Detection - Data Exploration
#
# This notebook provides interactive exploration of:
# 1. Simulated time series data patterns
# 2. Anomaly injection behavior
# 3. Model reconstruction quality
# 4. Scoring and threshold calibration
